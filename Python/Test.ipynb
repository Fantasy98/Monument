# %%
import tensorflow as tf 
from tensorflow import keras
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd 
import os
import shutil

# %%
import random


img_path = "E:\\Monument\\Monument raw\\"
img_list = os.listdir(img_path)
img_list = [os.path.join(img_path,i) for i in img_list]
random.shuffle(img_list)
img_rand = img_list[0]
img_rand_img = keras.utils.load_img(img_rand)
img_array = keras.utils.img_to_array(img_rand_img)/255

# %%
img_array.shape
# Out:
# (2748, 3840, 3)

# %%
plt.imshow(img_array[:,:,0])

# %%
from keras.preprocessing.image import ImageDataGenerator
gen = ImageDataGenerator(
                                rescale=1.0/255,
                                samplewise_center=True,
                                samplewise_std_normalization=True
                        )
gen = gen.flow_from_directory(directory="E:\\Monument\\Training",class_mode=None)
# Out:
# Found 156 images belonging to 1 classes.

# %%
img_test = gen[1][1]

# %%
plt.imshow(img_test)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
